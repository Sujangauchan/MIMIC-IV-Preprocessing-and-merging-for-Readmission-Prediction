# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("all_merged.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317483 entries, 0 to 317482
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   subject_id_x                   317483 non-null  int64
#  1   hadm_id                        317483 non-null  int64
#  2   admittime                      317483 non-null  object
#  3   dischtime                      317483 non-null  object
#  4   deathtime                      0 non-null       float64
#  5   admission_type                 317483 non-null  object
#  6   admit_provider_id              317479 non-null  object
#  7   admission_location             317483 non-null  object
#  8   discharge_location             270524 non-null  object
#  9   insurance                      313920 non-null  object
#  10  language                       317034 non-null  object
#  11  marital_status                 311030 non-null  object
# ...

# %%
df_tabular = df.loc[:, ~df.columns.isin(['procedures_last_5_icd_codes_x', 'procedures_last_5_icd_codes_y','diagnoses_last_5_icd_codes_x','diagnoses_last_5_icd_codes_y','text'])]

# %%
df_tabular
# Out:
#         subject_id_x   hadm_id            admittime            dischtime  \
# 0           10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1           10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2           10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 3           10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 4           10000084  23052089  2160-11-21 01:56:00  2160-11-25 14:52:00
# ...              ...       ...                  ...                  ...
# 317478      19999784  24755486  2121-05-30 09:22:00  2121-06-05 08:48:00
# 317479      19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 317480      19999828  25744818  2149-01-08 16:44:00  2149-01-18 17:00:00
# 317481      19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 317482      19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#         deathtime admission_type admit_provider_id      admission_location  \
# ...

# %%
df_tabular.to_csv("df_tabular.csv", index = False)

# %%
df_bert= df[["hadm_id","readmission_30day", "text", "procedures_last_5_icd_codes_x","diagnoses_last_5_icd_codes_x"]].copy()

# %%
df_bert['text'] = df_bert[['procedures_last_5_icd_codes_x', 'diagnoses_last_5_icd_codes_x','text']].apply(
    lambda x: ' '.join(x.astype(str)), axis=1
)

# %%
df_bert = df_bert[["hadm_id",'text',"readmission_30day"]]

df_bert.to_csv("bert_df")
