# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("proc_labevents.csv")

# %%
df
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1         10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2         10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 3         10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 4         10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...            ...       ...                  ...                  ...
# 525775    19999784  21364559  2124-03-23 00:00:00  2124-03-29 13:16:00
# 525776    19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 525777    19999828  25744818  2149-01-08 16:44:00  2149-01-18 17:00:00
# 525778    19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 525779    19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#         deathtime  admission_type admit_provider_id      admission_location  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525780 entries, 0 to 525779
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   subject_id                     525780 non-null  int64
#  1   hadm_id                        525780 non-null  int64
#  2   admittime                      525780 non-null  object
#  3   dischtime                      525780 non-null  object
#  4   deathtime                      0 non-null       float64
#  5   admission_type                 525780 non-null  object
#  6   admit_provider_id              525776 non-null  object
#  7   admission_location             525779 non-null  object
#  8   discharge_location             376619 non-null  object
#  9   insurance                      516830 non-null  object
#  10  language                       525161 non-null  object
#  11  marital_status                 514189 non-null  object
# ...

# %%
medical_notes = pd.read_csv("/Users/sujangauchan/Desktop/MIMIC csv/mimic-iv-note-deidentified-free-text-clinical-notes-2/note/discharge.csv")

# %%
medical_notes
# Out:
#                note_id  subject_id   hadm_id note_type  note_seq  \
# 0       10000032-DS-21    10000032  22595853        DS        21
# 1       10000032-DS-22    10000032  22841357        DS        22
# 2       10000032-DS-23    10000032  29079034        DS        23
# 3       10000032-DS-24    10000032  25742920        DS        24
# 4       10000084-DS-17    10000084  23052089        DS        17
# ...                ...         ...       ...       ...       ...
# 331788   19999828-DS-6    19999828  29734428        DS         6
# 331789   19999828-DS-7    19999828  25744818        DS         7
# 331790  19999840-DS-20    19999840  26071774        DS        20
# 331791  19999840-DS-21    19999840  21033226        DS        21
# 331792   19999987-DS-2    19999987  23865745        DS         2
#
#                   charttime            storetime  \
# 0       2180-05-07 00:00:00  2180-05-09 15:26:00
# 1       2180-06-27 00:00:00  2180-07-01 10:15:00
# ...

# %%
df = df.merge(medical_notes, on = "hadm_id", how = "left")
df
# Out:
#         subject_id_x   hadm_id            admittime            dischtime  \
# 0           10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1           10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2           10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 3           10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 4           10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...              ...       ...                  ...                  ...
# 525775      19999784  21364559  2124-03-23 00:00:00  2124-03-29 13:16:00
# 525776      19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 525777      19999828  25744818  2149-01-08 16:44:00  2149-01-18 17:00:00
# 525778      19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 525779      19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#         deathtime  admission_type admit_provider_id      admission_location  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525780 entries, 0 to 525779
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   subject_id_x                   525780 non-null  int64
#  1   hadm_id                        525780 non-null  int64
#  2   admittime                      525780 non-null  object
#  3   dischtime                      525780 non-null  object
#  4   deathtime                      0 non-null       float64
#  5   admission_type                 525780 non-null  object
#  6   admit_provider_id              525776 non-null  object
#  7   admission_location             525779 non-null  object
#  8   discharge_location             376619 non-null  object
#  9   insurance                      516830 non-null  object
#  10  language                       525161 non-null  object
#  11  marital_status                 514189 non-null  object
# ...

# %% [markdown]
# # Feature selection to use for prediction

# %% [markdown]
# #### Filtering admissions having discharge notes

# %%
df= df[df["text"].notnull()]
df
# Out:
#         subject_id_x   hadm_id            admittime            dischtime  \
# 0           10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1           10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2           10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 3           10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 5           10000084  23052089  2160-11-21 01:56:00  2160-11-25 14:52:00
# ...              ...       ...                  ...                  ...
# 525764      19999784  24755486  2121-05-30 09:22:00  2121-06-05 08:48:00
# 525776      19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 525777      19999828  25744818  2149-01-08 16:44:00  2149-01-18 17:00:00
# 525778      19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 525779      19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#         deathtime admission_type admit_provider_id      admission_location  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 317483 entries, 0 to 525779
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   subject_id_x                   317483 non-null  int64
#  1   hadm_id                        317483 non-null  int64
#  2   admittime                      317483 non-null  object
#  3   dischtime                      317483 non-null  object
#  4   deathtime                      0 non-null       float64
#  5   admission_type                 317483 non-null  object
#  6   admit_provider_id              317479 non-null  object
#  7   admission_location             317483 non-null  object
#  8   discharge_location             270524 non-null  object
#  9   insurance                      313920 non-null  object
#  10  language                       317034 non-null  object
#  11  marital_status                 311030 non-null  object
# ...

# %%
df["readmission_30day"].value_counts()
# Out:
# readmission_30day
# 0    247351
# 1     70132
# Name: count, dtype: int64

# %%
df["subject_id_x"].nunique()
# Out:
# 140065

# %%
df.to_csv("all_merged")
